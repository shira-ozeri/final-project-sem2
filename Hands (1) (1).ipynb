# %% [markdown]
# # 👋🏼☝🏻✌🏽 Hands movemants ✌🏽☝🏻👋🏼
#
#
#
# The goal: to classify between three different situations in the way people communicate with each other.
# The first is Spontaneous (autonomous) situation in which two people move their hands freely in front of each other.
# The second is a synchronous movement in which the two people move their hands together and the third is a movement in position
# Own. Where only one side moves the hands.
# The idea is to look at the patterns of the hands and try to deduce from them whether it is a situation alone, spontaneous or synchronous.

# %%
import numpy as np
import pandas as pd
from pandas import Series
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning)
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
#from xgboost import XGBClassifier
import os
import cv2
import time
from tqdm import tqdm
from random import shuffle
import random

# %% [markdown]
# ### Importing and arranging data

# %%
#legend: 0-Spontan 1-Alone 2-Sync
#validation
Evyatar0 = pd.read_csv(r"C:\datahands\Training\Evyatar Cohen\Evyatar636771052727603804Spontan.csv")
Evyatar1 = pd.read_csv(r"C:\datahands\Training\Evyatar Cohen\Evyatar636771054555711409Alone.csv")
Evyatar2 = pd.read_csv(r"C:\datahands\Training\Evyatar Cohen\Evyatar636771053639929594Sync.csv")

#Training set
Nofar0 = pd.read_csv(r"C:\datahands\Training\Nofar Social_Nuero\Nofar636759795182793299Spontan.csv")
Nofar1 = pd.read_csv(r"C:\datahands\Training\Nofar Social_Nuero\Nofar636759796290435160Alone.csv")
Nofar2 = pd.read_csv(r"C:\datahands\Training\Nofar Social_Nuero\Nofar636759797397919664Sync.csv")

Oriya0 = pd.read_csv(r"C:\datahands\Training\Oriya Social_Nuero\Oriya636759804404113837Spontan.csv")
Oriya1 = pd.read_csv(r"C:\datahands\Training\Oriya Social_Nuero\Oriya636759805268396661Alone.csv")
Oriya2 = pd.read_csv(r"C:\datahands\Training\Oriya Social_Nuero\Oriya636759806131350399Sync.csv")

Orya0 = pd.read_csv(r"C:\datahands\Training\Orya Kalmanovitz\OryaB636771083605535985Spontan.csv")
Orya1 = pd.read_csv(r"C:\datahands\Training\Orya Kalmanovitz\OryaB636771082736601528Alone.csv")
Orya2 = pd.read_csv(r"C:\datahands\Training\Orya Kalmanovitz\OryaB636771084494502229Sync.csv")

Revital0 = pd.read_csv(r"C:\datahands\Training\Revital Marbel\Revital636770957038873193Spontan.csv")
Revital1 = pd.read_csv(r"C:\datahands\Training\Revital Marbel\Revital636770955999435879Alone.csv")
Revital2 = pd.read_csv(r"C:\datahands\Training\Revital Marbel\Revital636770957894370062Sync.csv")

Shahar0 = pd.read_csv(r"C:\datahands\Training\Shahar Terner\Sachar636771045591258071Spontan.csv")
Shahar1 = pd.read_csv(r"C:\datahands\Training\Shahar Terner\Sachar636771047408504303Alone.csv")
Shahar2 = pd.read_csv(r"C:\datahands\Training\Shahar Terner\Sachar636771046527112972Sync.csv")

Shelly0 = pd.read_csv(r"C:\datahands\Training\Shelly Social_Nuero\Shelly636759787508979097Spontan.csv")
Shelly1 = pd.read_csv(r"C:\datahands\Training\Shelly Social_Nuero\Shelly636759788383205274Alone.csv")
Shelly2 = pd.read_csv(r"C:\datahands\Training\Shelly Social_Nuero\Shelly636759789526313406Sync.csv")

Yael0 = pd.read_csv(r"C:\datahands\Training\Yael Hagai\Yael636771059544754823Spontan.csv")
Yael1 = pd.read_csv(r"C:\datahands\Training\Yael Hagai\Yael636771061659067649Alone.csv")
Yael2 = pd.read_csv(r"C:\datahands\Training\Yael Hagai\Yael636771060699529085Sync.csv")

Yoel0 = pd.read_csv(r"C:\datahands\Training\Yoel Raz\Yoel636760921663075813Spontan.csv")
Yoel1 = pd.read_csv(r"C:\datahands\Training\Yoel Raz\Yoel636760922573364655Alone.csv")
Yoel2 = pd.read_csv(r"C:\datahands\Training\Yoel Raz\Yoel636760923490742912Sync.csv")

#testing set
Itiel0 = pd.read_csv(r"C:\datahands\Validation\Itiel Lab\Itiel636770940701219076Spontan.csv")
Itiel1 = pd.read_csv(r"C:\datahands\Validation\Itiel Lab\Itiel636770942529041679Alone.csv")
Itiel2 = pd.read_csv(r"C:\datahands\Validation\Itiel Lab\Itiel636770941638547912Sync.csv")

Mor0 = pd.read_csv(r"C:\datahands\Validation\Mor SHerman\Mor636771064635567065Spontan.csv")
Mor1 = pd.read_csv(r"C:\datahands\Validation\Mor SHerman\Mor636771066407626524Alone.csv")
Mor2 = pd.read_csv(r"C:\datahands\Validation\Mor SHerman\Mor636771065531910215Sync.csv")

Oded0 = pd.read_csv(r"C:\datahands\Validation\Oded Medina\Oded636754670490266956Spontan.csv")
Oded1 = pd.read_csv(r"C:\datahands\Validation\Oded Medina\Oded636754669540564461Alone.csv")
Oded2 = pd.read_csv(r"C:\datahands\Validation\Oded Medina\Oded636754671560850581Sync.csv")

handRight = pd.read_csv(r"C:\datahands\HandRight.csv")

# %%
#Spontaneous alone and synchronized lists of train (including validation)
lst0train=[Evyatar0, Nofar0, Oriya0, Orya0, Revital0, Shahar0, Shelly0, Yael0, Yoel0]
lst1train=[Evyatar1, Nofar1, Oriya1, Orya1, Revital1, Shahar1, Shelly1, Yael1, Yoel1]
lst2train=[Evyatar2, Nofar2, Oriya2, Orya2, Revital2, Shahar2, Shelly2, Yael2, Yoel2]
lst012train= lst0train + lst1train + lst2train
#Of test 
lst0ft=[Itiel0, Mor0, Oded0]
lst1ft=[Itiel1, Mor1, Oded1]
lst2ft=[Itiel2, Mor2, Oded2]
lst012ft= lst0ft + lst1ft + lst2ft

# %%
#Checking NaN values
#On the train
counTrain = 0
for i in range(len(lst012train)):
    counTrain += lst012train[i].isna().sum().sum()
counTrain
# Out:
# 0

# %%
#on test
counTest = 0
for i in range(len(lst012ft)):
    counTest += lst012ft[i].isna().sum().sum()
counTest
# Out:
# 0

# %%
#on handright
handRight.isna().sum().sum()
# Out:
# 2304

# %%
#cleaning
handRight.dropna(inplace=True)
handRight.isnull().sum()
# Out:
# Time               0
#  Frame ID          0
#  Hand Type         0
#  # hands           0
#  Position X        0
#  Position Y        0
#  Position Z        0
#  Velocity X        0
#  Velocity Y        0
#  Velocity Z        0
#  Pitch             0
#  Roll              0
#  Yaw               0
#  Wrist Pos X       0
#  Wrist Pos Y       0
#  Wrist Pos Z       0
#  Elbow pos X       0
#  Elbow Pos Y       0
#  Elbow Pos Z       0
#  Grab Strenth      0
#  Grab Angle        0
#  Pinch Strength    0
# dtype: int64

# %%
#  Start from second 7 in the train including validation
print('Example df length before: '+str(len(lst1train[1])))# frames in Alone second dataframe
for scenario in (lst0train,lst1train,lst2train):
    for df in scenario:
        df.drop(range(2*6*7),inplace=True)
print('Example df length after: '+str(len(lst1train[1])))
# Out:
# Example df length before: 4575
# Example df length after: 4491

# %%
#  Start from second 7 in the test
print('Example df length before: '+str(len(lst0ft[0])))# frames in Alone second dataframe
for scenario in (lst0ft,lst1ft,lst2ft):
    for df in scenario:
        df.drop(range(2*6*7),inplace=True)
print('Example df length after: '+str(len(lst0ft[0])))
# Out:
# Example df length before: 8969
# Example df length after: 8885

# %%
#Spontaneous solo and synchronized lists of train (without validation)
lst0train=[Nofar0, Oriya0, Orya0, Revital0, Shahar0, Shelly0, Yael0, Yoel0]
lst1train=[Nofar1, Oriya1, Orya1, Revital1, Shahar1, Shelly1, Yael1, Yoel1]
lst2train=[Nofar2, Oriya2, Orya2, Revital2, Shahar2, Shelly2, Yael2, Yoel2]
lst012train= lst0train + lst1train + lst2train
# We will issue the validation separately
valid= [Evyatar0,Evyatar1,Evyatar2]

# %%
#Impressive for Data Prame
#TRAIN
#Spontaneous
DF0train=pd.concat(lst0train).reset_index(drop=True)
#alone
DF1train=pd.concat(lst1train).reset_index(drop=True)
#sync
DF2train=pd.concat(lst2train).reset_index(drop=True)
# VALIDATION
DFvalid=pd.concat(valid).reset_index(drop=True)
#TEST 
#Spontaneous
DF0ft=pd.concat(lst0ft).reset_index(drop=True)
#alone
DF1ft=pd.concat(lst1ft).reset_index(drop=True)
#sync
DF2ft=pd.concat(lst2ft).reset_index(drop=True)

# %%
#Attach the right to each alone

# %%
#TRAIN
DF1train
# Out:
#            Time   Frame ID  Hand Type   # hands   Position X   Position Y  \
# 0      497.4586      58347       left         1    -44.18128     165.8195
# 1      497.4752      58349       left         1    -44.26361     163.6069
# 2      497.4918      58351       left         1    -44.44040     162.4174
# 3      497.5088      58353       left         1    -45.04150     162.9086
# 4      497.5249      58355       left         1    -45.98182     164.0980
# ...         ...        ...        ...       ...          ...          ...
# 33619  764.4578      59984       left         1   -125.81370     214.8894
# 33620  764.4913      59986       left         1   -125.92320     215.6769
# 33621  764.5253      59988       left         1   -125.62170     215.7428
# 33622  764.5587      59989       left         1   -125.13520     215.6353
# 33623  764.5913      59991       left         1   -123.99810     215.1558
#
#         Position Z   Velocity X   Velocity Y   Velocity Z  ...       Yaw  \
# 0         18.78671     3.787952  -136.611800   -47.571530  ...  1.682755
# 1         17.85721    -5.235297  -125.426000   -52.429120  ...  1.687096
# 2         17.03447   -19.420500   -49.001460   -46.000750  ...  1.689885
# 3         16.24598   -37.374070    38.480630   -45.237350  ...  1.692895
# 4         15.50213   -64.747180    95.347340   -41.739730  ...  1.695563
# ...            ...          ...          ...          ...  ...       ...
# 33619     20.59324    20.170870    19.997410    37.082170  ...  0.409534
# 33620     22.09264    -6.867068    21.957800    42.485630  ...  0.399021
# 33621     23.39750    17.454730    -3.217659    31.446690  ...  0.379251
# 33622     23.80248    25.567410    -5.648659    21.284490  ...  0.368866
# 33623     24.26945    30.369090   -15.233250     6.734551  ...  0.373039
#
#         Wrist Pos X   Wrist Pos Y   Wrist Pos Z   Elbow pos X   Elbow Pos Y  \
# 0         -114.6894      167.1053      2.444844     -339.3897      53.82746
# 1         -114.4097      167.8733      1.127433     -336.8071      52.07711
# 2         -114.2073      168.9353      0.130770     -333.6935      49.07627
# 3         -114.4628      170.7293     -0.806436     -329.6519      44.20391
# 4         -115.1224      172.6726     -1.665721     -326.1113      39.14006
# ...             ...           ...           ...           ...           ...
# 33619     -146.6314      148.2971     44.407660     -258.0887     -77.52971
# 33620     -146.1113      148.8045     45.689300     -253.6847     -80.13625
# 33621     -144.8174      148.4588     46.660750     -249.6531     -83.33176
# 33622     -143.8482      148.1024     46.728610     -248.2768     -84.26936
# 33623     -142.6839      147.4703     46.755790     -247.4121     -84.85361
#
#         Elbow Pos Z   Grab Strenth   Grab Angle   Pinch Strength
# 0         -59.05448       0.000000     0.505916         0.025057
# 1         -63.94888       0.000000     0.753651         0.000000
# 2         -67.42601       0.000000     1.100223         0.000000
# 3         -70.01109       0.000000     1.515047         0.000000
# 4         -70.63696       0.000000     1.474850         0.000000
# ...             ...            ...          ...              ...
# 33619     112.97060       0.116068     1.901876         0.000000
# 33620     109.99670       0.134497     1.952747         0.000000
# 33621     105.00430       0.120680     1.984825         0.000000
# 33622     103.46830       0.097735     1.988376         0.000000
# 33623     103.13800       0.065015     1.989704         0.016533
#
# [33624 rows x 22 columns]

# %%
handRight
# Out:
#           Time   Frame ID  Hand Type   # hands   Position X   Position Y  \
# 0     128.2883      15478      right         1    15.671670     226.2064
# 1     128.3048      15480      right         1    16.241190     222.9389
# 2     128.3218      15482      right         1    16.724610     220.9709
# 3     128.3384      15484      right         1    17.090160     219.7124
# 4     128.3551      15486      right         1    17.460170     219.3652
# ...        ...        ...        ...       ...          ...          ...
# 4423  201.7963      23950       left         1    -0.323175     133.7385
# 4424  201.8130      23952       left         1    -0.147323     129.7719
# 4425  201.8304      23954       left         1    -0.362086     125.4905
# 4426  201.8472      23956       left         1    -0.431924     121.2493
# 4427  201.8637      23958       left         1     0.005894     118.1600
#
#        Position Z   Velocity X   Velocity Y   Velocity Z  ...       Yaw  \
# 0        20.26470    34.266650  -195.214700   -35.043020  ... -0.277800
# 1        20.11781    36.164430  -180.093900    -4.052799  ... -0.277763
# 2        19.94972    26.352980   -95.088190   -11.157620  ... -0.278792
# 3        19.67679    19.468040   -61.755180   -21.303780  ... -0.279768
# 4        19.13128    21.949640    -8.355943   -35.081790  ... -0.278629
# ...           ...          ...          ...          ...  ...       ...
# 4423    101.87010     1.267956  -281.917800   319.237200  ...  0.014095
# 4424    106.21060    -9.675756  -231.337500   248.109700  ...  0.038956
# 4425    107.51370     0.578270  -205.407100    86.839940  ...  0.039169
# 4426    107.08130    -0.375302  -235.595100   -55.290660  ...  0.036723
# 4427    104.59190    32.424800  -145.061300  -160.387800  ...  0.033038
#
#        Wrist Pos X   Wrist Pos Y   Wrist Pos Z   Elbow pos X   Elbow Pos Y  \
# 0        46.888310     207.35480      86.23589     203.83370      49.33507
# 1        47.548610     205.65680      86.42250     203.95530      47.88272
# 2        48.150300     204.51820      86.35149     204.62310      45.35921
# 3        48.641750     203.99890      86.16056     204.99390      44.18692
# 4        48.931350     203.37770      85.59017     204.59520      42.68003
# ...            ...           ...           ...           ...           ...
# 4423      1.693034     105.98620     171.82360    -108.34840     -93.43824
# 4424      0.450534     104.88660     177.28050    -104.47600     -95.64841
# 4425      0.317466     103.76150     179.51640     -98.71099    -100.80110
# 4426      0.433988     101.23320     179.47840     -94.49784    -108.06140
# 4427      1.035182      98.47138     176.97720     -92.41229    -115.88370
#
#        Elbow Pos Z   Grab Strenth   Grab Angle   Pinch Strength
# 0         237.4553            0.0     0.206389              0.0
# 1         238.4482            0.0     0.243050              0.0
# 2         236.8544            0.0     0.281134              0.0
# 3         236.0927            0.0     0.277691              0.0
# 4         235.2896            0.0     0.283008              0.0
# ...            ...            ...          ...              ...
# 4423      319.8367            0.0     0.133462              0.0
# 4424      327.4911            0.0     0.100465              0.0
# 4425      328.2934            0.0     0.202968              0.0
# 4426      324.2915            0.0     0.261246              0.0
# 4427      315.2038            0.0     0.287836              0.0
#
# [4428 rows x 22 columns]

# %%
def merge_df(df1,df2):

    index=np.arange(0,df1.shape[0])
    df1['key']=index
    df2['key']=index

    df=pd.merge(df1,df2,how="outer", on="key")
    df = df.drop(columns=['key'])
    return df

# %%
##It is made that the right will have the same number of rows as the felt to unite them afterwards
handRight2 = pd.read_csv(r"C:\datahands\HandRight.csv")


handRight=pd.concat([handRight2,handRight2])
handRight=pd.concat([handRight2,handRight])
handRight=pd.concat([handRight2,handRight])
handRight=pd.concat([handRight2,handRight])
handRight=pd.concat([handRight2,handRight])
handRight=pd.concat([handRight2,handRight])
handRight =handRight.iloc[0:DF1train.shape[0], :]
handRight.shape
# Out:
# (33624, 22)

# %%
#Consolidation
newDF1train=merge_df(handRight,DF1train)
newDF1train.shape
# Out:
# (33624, 44)

# %%
#VALID...

# %%
Evyatar1.shape
# Out:
# (4442, 22)

# %%
##It is made that the right will have the same number of rows as the felt to unite them afterwards
handRight2 =handRight2.iloc[0:Evyatar1.shape[0], :]
#Consolidation and update of validation
newEvyatar1=merge_df(handRight2,Evyatar1)
valid= [Evyatar0,newEvyatar1,Evyatar2]
newEvyatar1.shape
# Out:
# (4442, 44)

# %%
#TEST
DF1ft.shape
# Out:
# (11312, 22)

# %%
handRight3 = pd.read_csv(r"C:\datahands\HandRight.csv")



handRight=pd.concat([handRight3,handRight3])
handRight=pd.concat([handRight3,handRight])
handRight=pd.concat([handRight3,handRight])
handRight=pd.concat([handRight3,handRight])
handRight=pd.concat([handRight3,handRight])
handRight =handRight.iloc[0:DF1ft.shape[0], :]
handRight.shape
# Out:
# (11312, 22)

# %%
#Consolidation
newDF1ft=merge_df(handRight,DF1ft)
newDF1ft.shape
# Out:
# (11312, 44)

# %%
DF0train = DF0train.rename(columns={' Frame ID': 'Frame_ID', ' Hand Type': 'Hand_Type',
                     ' # hands':'Number_of_hands', ' Position X': 'Position_X', ' Position Y': 'Position_Y',
                     ' Position Z': 'Position_Z', ' Velocity X': 'Velocity_X', ' Velocity Y': 'Velocity_Y',
                     ' Velocity Z': 'Velocity_Z', ' Pitch' : 'Pitch',  ' Roll': 'Roll', ' Yaw': 'Yaw',
                     ' Wrist Pos X': 'Wrist_Pos_X', ' Wrist Pos Y': 'Wrist_Pos_Y', ' Wrist Pos Z': 'Wrist_Pos_Z',
                     ' Elbow pos X': 'Elbow_Pos_X',  ' Elbow Pos Y':  'Elbow_Pos_Y', ' Elbow Pos Z': 'Elbow_Pos_Z',
                     ' Grab Strenth': 'Grab_Strenth', ' Grab Angle': 'Grab_Angle',' Pinch Strength': 'Pinch_Strength'})
newDF1train = newDF1train.rename(columns={           'Time_x':         'Time_x',   ' Hand Type_x':' Hand_Type_x',    ' # hands_x'      :' Number_of_hands_x'  ,
     ' Position X_x':  ' Position_X_x',  ' Position Y_x':' Position_Y_x',   ' Position Z_x'   :' Position_Z_x' ,
     ' Velocity X_x':  ' Velocity_X_x',  ' Velocity Y_x':' Velocity_Y_x',   ' Velocity Z_x'   :' Velocity_Z_x' ,
          ' Pitch_x':       ' Pitch_x',        ' Roll_x':' Roll_x',         ' Yaw_x'          :' Yaw_x'       ,
    ' Wrist Pos X_x': ' Wrist_Pos_X_x', ' Wrist Pos Y_x':' Wrist_Pos_Y_x',  ' Wrist Pos Z_x'  :' Wrist_Pos_Z_x',
    ' Elbow pos X_x': ' Elbow_pos_X_x', ' Elbow Pos Y_x':' Elbow_Pos_Y_x',  ' Elbow Pos Z_x'  :' Elbow_Pos_Z_x',
   ' Grab Strenth_x':' Grab_Strenth_x',  ' Grab Angle_x':' Grab_Angle_x',   ' Pinch Strength_x':' Pinch_Strength_x',
            'Time_y':         'Time_y',   ' Hand Type_y':' Hand_Type_y',    ' # hands_y'      :' Number_of_hands_y'  ,
     ' Position X_y':  ' Position_X_y',  ' Position Y_y':' Position_Y_y',   ' Position Z_y'   :' Position_Z_y' ,
     ' Velocity X_y':  ' Velocity_X_y',  ' Velocity Y_y':' Velocity_Y_y',  ' Velocity Z_y'   :' Velocity_Z_y',
          ' Pitch_y':       ' Pitch_y',        ' Roll_y':' Roll_y',        ' Yaw_y'          :' Yaw_y'      ,
    ' Wrist Pos X_y': ' Wrist_Pos_X_y', ' Wrist Pos Y_y':' Wrist_Pos_Y_y', ' Wrist Pos Z_y'  :' Wrist_Pos_Z_y',
    ' Elbow pos X_y': ' Elbow_pos_X_y', ' Elbow Pos Y_y':' Elbow_Pos_Y_y', ' Elbow Pos Z_y'  :' Elbow_Pos_Z_y',
   ' Grab Strenth_y':' Grab Strenth_y',  ' Grab Angle_y':' Grab_Angle_y',  ' Pinch Strength_y':' Pinch_Strength_y',
          'Category':'Category'})
DF2train = DF2train.rename(columns={' Frame ID': 'Frame_ID', ' Hand Type': 'Hand_Type',
                     ' # hands':'Number_of_hands', ' Position X': 'Position_X', ' Position Y': 'Position_Y',
                     ' Position Z': 'Position_Z', ' Velocity X': 'Velocity_X', ' Velocity Y': 'Velocity_Y',
                     ' Velocity Z': 'Velocity_Z', ' Pitch' : 'Pitch',  ' Roll': 'Roll', ' Yaw': 'Yaw',
                     ' Wrist Pos X': 'Wrist_Pos_X', ' Wrist Pos Y': 'Wrist_Pos_Y', ' Wrist Pos Z': 'Wrist_Pos_Z',
                     ' Elbow pos X': 'Elbow_Pos_X',  ' Elbow Pos Y':  'Elbow_Pos_Y', ' Elbow Pos Z': 'Elbow_Pos_Z',
                     ' Grab Strenth': 'Grab_Strenth', ' Grab Angle': 'Grab_Angle',' Pinch Strength': 'Pinch_Strength'})
DF0ft = DF0ft.rename(columns={' Frame ID': 'Frame_ID', ' Hand Type': 'Hand_Type',
                     ' # hands':'Number_of_hands', ' Position X': 'Position_X', ' Position Y': 'Position_Y',
                     ' Position Z': 'Position_Z', ' Velocity X': 'Velocity_X', ' Velocity Y': 'Velocity_Y',
                     ' Velocity Z': 'Velocity_Z', ' Pitch' : 'Pitch',  ' Roll': 'Roll', ' Yaw': 'Yaw',
                     ' Wrist Pos X': 'Wrist_Pos_X', ' Wrist Pos Y': 'Wrist_Pos_Y', ' Wrist Pos Z': 'Wrist_Pos_Z',
                     ' Elbow pos X': 'Elbow_Pos_X',  ' Elbow Pos Y':  'Elbow_Pos_Y', ' Elbow Pos Z': 'Elbow_Pos_Z',
                     ' Grab Strenth': 'Grab_Strenth', ' Grab Angle': 'Grab_Angle',' Pinch Strength': 'Pinch_Strength'})
newDF1ft = newDF1ft.rename(columns={           'Time_x':         'Time_x',   ' Hand Type_x':' Hand_Type_x',    ' # hands_x'      :' Number_of_hands_x'  ,
     ' Position X_x':  ' Position_X_x',  ' Position Y_x':' Position_Y_x',   ' Position Z_x'   :' Position_Z_x' ,
     ' Velocity X_x':  ' Velocity_X_x',  ' Velocity Y_x':' Velocity_Y_x',   ' Velocity Z_x'   :' Velocity_Z_x' ,
          ' Pitch_x':       ' Pitch_x',        ' Roll_x':' Roll_x',         ' Yaw_x'          :' Yaw_x'       ,
    ' Wrist Pos X_x': ' Wrist_Pos_X_x', ' Wrist Pos Y_x':' Wrist_Pos_Y_x',  ' Wrist Pos Z_x'  :' Wrist_Pos_Z_x',
    ' Elbow pos X_x': ' Elbow_pos_X_x', ' Elbow Pos Y_x':' Elbow_Pos_Y_x',  ' Elbow Pos Z_x'  :' Elbow_Pos_Z_x',
   ' Grab Strenth_x':' Grab_Strenth_x',  ' Grab Angle_x':' Grab_Angle_x',   ' Pinch Strength_x':' Pinch_Strength_x',
            'Time_y':         'Time_y',   ' Hand Type_y':' Hand_Type_y',    ' # hands_y'      :' Number_of_hands_y'  ,
     ' Position X_y':  ' Position_X_y',  ' Position Y_y':' Position_Y_y',   ' Position Z_y'   :' Position_Z_y' ,
     ' Velocity X_y':  ' Velocity_X_y',  ' Velocity Y_y':' Velocity_Y_y',  ' Velocity Z_y'   :' Velocity_Z_y',
          ' Pitch_y':       ' Pitch_y',        ' Roll_y':' Roll_y',        ' Yaw_y'          :' Yaw_y'      ,
    ' Wrist Pos X_y': ' Wrist_Pos_X_y', ' Wrist Pos Y_y':' Wrist_Pos_Y_y', ' Wrist Pos Z_y'  :' Wrist_Pos_Z_y',
    ' Elbow pos X_y': ' Elbow_pos_X_y', ' Elbow Pos Y_y':' Elbow_Pos_Y_y', ' Elbow Pos Z_y'  :' Elbow_Pos_Z_y',
   ' Grab Strenth_y':' Grab Strenth_y',  ' Grab Angle_y':' Grab_Angle_y',  ' Pinch Strength_y':' Pinch_Strength_y',
          'Category':'Category'})
DF2ft = DF2ft.rename(columns={' Frame ID': 'Frame_ID', ' Hand Type': 'Hand_Type',
                     ' # hands':'Number_of_hands', ' Position X': 'Position_X', ' Position Y': 'Position_Y',
                     ' Position Z': 'Position_Z', ' Velocity X': 'Velocity_X', ' Velocity Y': 'Velocity_Y',
                     ' Velocity Z': 'Velocity_Z', ' Pitch' : 'Pitch',  ' Roll': 'Roll', ' Yaw': 'Yaw',
                     ' Wrist Pos X': 'Wrist_Pos_X', ' Wrist Pos Y': 'Wrist_Pos_Y', ' Wrist Pos Z': 'Wrist_Pos_Z',
                     ' Elbow pos X': 'Elbow_Pos_X',  ' Elbow Pos Y':  'Elbow_Pos_Y', ' Elbow Pos Z': 'Elbow_Pos_Z',
                     ' Grab Strenth': 'Grab_Strenth', ' Grab Angle': 'Grab_Angle',' Pinch Strength': 'Pinch_Strength'})
Evyatar0 = Evyatar0.rename(columns={' Frame ID': 'Frame_ID', ' Hand Type': 'Hand_Type',
                     ' # hands':'Number_of_hands', ' Position X': 'Position_X', ' Position Y': 'Position_Y',
                     ' Position Z': 'Position_Z', ' Velocity X': 'Velocity_X', ' Velocity Y': 'Velocity_Y',
                     ' Velocity Z': 'Velocity_Z', ' Pitch' : 'Pitch',  ' Roll': 'Roll', ' Yaw': 'Yaw',
                     ' Wrist Pos X': 'Wrist_Pos_X', ' Wrist Pos Y': 'Wrist_Pos_Y', ' Wrist Pos Z': 'Wrist_Pos_Z',
                     ' Elbow pos X': 'Elbow_Pos_X',  ' Elbow Pos Y':  'Elbow_Pos_Y', ' Elbow Pos Z': 'Elbow_Pos_Z',
                     ' Grab Strenth': 'Grab_Strenth', ' Grab Angle': 'Grab_Angle',' Pinch Strength': 'Pinch_Strength'})
newEvyatar1 = newEvyatar1.rename(columns={           'Time_x':         'Time_x',   ' Hand Type_x':' Hand_Type_x',    ' # hands_x'      :' Number_of_hands_x'  ,
     ' Position X_x':  ' Position_X_x',  ' Position Y_x':' Position_Y_x',   ' Position Z_x'   :' Position_Z_x' ,
     ' Velocity X_x':  ' Velocity_X_x',  ' Velocity Y_x':' Velocity_Y_x',   ' Velocity Z_x'   :' Velocity_Z_x' ,
          ' Pitch_x':       ' Pitch_x',        ' Roll_x':' Roll_x',         ' Yaw_x'          :' Yaw_x'       ,
    ' Wrist Pos X_x': ' Wrist_Pos_X_x', ' Wrist Pos Y_x':' Wrist_Pos_Y_x',  ' Wrist Pos Z_x'  :' Wrist_Pos_Z_x',
    ' Elbow pos X_x': ' Elbow_pos_X_x', ' Elbow Pos Y_x':' Elbow_Pos_Y_x',  ' Elbow Pos Z_x'  :' Elbow_Pos_Z_x',
   ' Grab Strenth_x':' Grab_Strenth_x',  ' Grab Angle_x':' Grab_Angle_x',   ' Pinch Strength_x':' Pinch_Strength_x',
            'Time_y':         'Time_y',   ' Hand Type_y':' Hand_Type_y',    ' # hands_y'      :' Number_of_hands_y'  ,
     ' Position X_y':  ' Position_X_y',  ' Position Y_y':' Position_Y_y',   ' Position Z_y'   :' Position_Z_y' ,
     ' Velocity X_y':  ' Velocity_X_y',  ' Velocity Y_y':' Velocity_Y_y',  ' Velocity Z_y'   :' Velocity_Z_y',
          ' Pitch_y':       ' Pitch_y',        ' Roll_y':' Roll_y',        ' Yaw_y'          :' Yaw_y'      ,
    ' Wrist Pos X_y': ' Wrist_Pos_X_y', ' Wrist Pos Y_y':' Wrist_Pos_Y_y', ' Wrist Pos Z_y'  :' Wrist_Pos_Z_y',
    ' Elbow pos X_y': ' Elbow_pos_X_y', ' Elbow Pos Y_y':' Elbow_Pos_Y_y', ' Elbow Pos Z_y'  :' Elbow_Pos_Z_y',
   ' Grab Strenth_y':' Grab Strenth_y',  ' Grab Angle_y':' Grab_Angle_y',  ' Pinch Strength_y':' Pinch_Strength_y',
          'Category':'Category'})
Evyatar2 = Evyatar2.rename(columns={' Frame ID': 'Frame_ID', ' Hand Type': 'Hand_Type',
                     ' # hands':'Number_of_hands', ' Position X': 'Position_X', ' Position Y': 'Position_Y',
                     ' Position Z': 'Position_Z', ' Velocity X': 'Velocity_X', ' Velocity Y': 'Velocity_Y',
                     ' Velocity Z': 'Velocity_Z', ' Pitch' : 'Pitch',  ' Roll': 'Roll', ' Yaw': 'Yaw',
                     ' Wrist Pos X': 'Wrist_Pos_X', ' Wrist Pos Y': 'Wrist_Pos_Y', ' Wrist Pos Z': 'Wrist_Pos_Z',
                     ' Elbow pos X': 'Elbow_Pos_X',  ' Elbow Pos Y':  'Elbow_Pos_Y', ' Elbow Pos Z': 'Elbow_Pos_Z',
                     ' Grab Strenth': 'Grab_Strenth', ' Grab Angle': 'Grab_Angle',' Pinch Strength': 'Pinch_Strength'})

# %% [markdown]
# Consolidation of 3 types of train movements into one data set

# %%
DF0train.columns.array
# Out:
# <PandasArray>
# [           'Time',        'Frame_ID',       'Hand_Type', 'Number_of_hands',
#       'Position_X',      'Position_Y',      'Position_Z',      'Velocity_X',
#       'Velocity_Y',      'Velocity_Z',           'Pitch',            'Roll',
#              'Yaw',     'Wrist_Pos_X',     'Wrist_Pos_Y',     'Wrist_Pos_Z',
#      'Elbow_Pos_X',     'Elbow_Pos_Y',     'Elbow_Pos_Z',    'Grab_Strenth',
#       'Grab_Angle',  'Pinch_Strength']
# Length: 22, dtype: object

# %%
DF2train.columns.array
# Out:
# <PandasArray>
# [           'Time',        'Frame_ID',       'Hand_Type', 'Number_of_hands',
#       'Position_X',      'Position_Y',      'Position_Z',      'Velocity_X',
#       'Velocity_Y',      'Velocity_Z',           'Pitch',            'Roll',
#              'Yaw',     'Wrist_Pos_X',     'Wrist_Pos_Y',     'Wrist_Pos_Z',
#      'Elbow_Pos_X',     'Elbow_Pos_Y',     'Elbow_Pos_Z',    'Grab_Strenth',
#       'Grab_Angle',  'Pinch_Strength']
# Length: 22, dtype: object

# %%
newDF1train.columns.array
# Out:
# <PandasArray>
# [            'Time_x',        ' Frame ID_x',       ' Hand_Type_x',
#  ' Number_of_hands_x',      ' Position_X_x',      ' Position_Y_x',
#       ' Position_Z_x',      ' Velocity_X_x',      ' Velocity_Y_x',
#       ' Velocity_Z_x',           ' Pitch_x',            ' Roll_x',
#              ' Yaw_x',     ' Wrist_Pos_X_x',     ' Wrist_Pos_Y_x',
#      ' Wrist_Pos_Z_x',     ' Elbow_pos_X_x',     ' Elbow_Pos_Y_x',
#      ' Elbow_Pos_Z_x',    ' Grab_Strenth_x',      ' Grab_Angle_x',
#   ' Pinch_Strength_x',             'Time_y',        ' Frame ID_y',
#        ' Hand_Type_y', ' Number_of_hands_y',      ' Position_X_y',
#       ' Position_Y_y',      ' Position_Z_y',      ' Velocity_X_y',
#       ' Velocity_Y_y',      ' Velocity_Z_y',           ' Pitch_y',
#             ' Roll_y',             ' Yaw_y',     ' Wrist_Pos_X_y',
#      ' Wrist_Pos_Y_y',     ' Wrist_Pos_Z_y',     ' Elbow_pos_X_y',
#      ' Elbow_Pos_Y_y',     ' Elbow_Pos_Z_y',    ' Grab Strenth_y',
#       ' Grab_Angle_y',  ' Pinch_Strength_y']
# Length: 44, dtype: object

# %%
#Preparation for Union Train
#DF0train.columns.array

#newDF1train.columns.array

DF0train = pd.merge(DF0train[DF0train['Hand_Type'] == 'left'], DF0train[DF0train['Hand_Type'] == 'right'], how='inner', on=['Frame_ID'])
DF2train = pd.merge(DF2train[DF2train['Hand_Type'] == 'left'], DF2train[DF2train['Hand_Type'] == 'right'], how='inner', on=['Frame_ID'])

#DF0train.columns.array

newDF1train = newDF1train.drop(columns=[' Frame ID_y',' Frame ID_x'])
DF0train= DF0train.drop(columns=['Frame_ID'])
DF2train= DF2train.drop(columns=['Frame_ID'])
DF0train['Category']='0'
DF2train['Category']='2'
newDF1train['Category']='1'

#DF0train.columns.array

#newDF1train.columns.array

#Preparation for Union test
DF0ft = pd.merge(DF0ft[DF0ft['Hand_Type'] == 'left'], DF0ft[DF0ft['Hand_Type'] == 'right'], how='inner', on=['Frame_ID'])
DF2ft = pd.merge(DF2ft[DF2ft['Hand_Type'] == 'left'], DF2ft[DF2ft['Hand_Type']== 'right'], how='inner', on=['Frame_ID'])

newDF1ft = newDF1ft.drop(columns=[' Frame ID_y',' Frame ID_x'])
DF0ft= DF0ft.drop(columns=['Frame_ID'])
DF2ft= DF2ft.drop(columns=['Frame_ID'])

DF0ft['Category']='0'
DF2ft['Category']='2'
newDF1ft['Category']='1'


#Preparation for Union valid...
Evyatar0 = pd.merge(Evyatar0[Evyatar0['Hand_Type'] == 'left'], Evyatar0[Evyatar0['Hand_Type'] == 'right'], how='inner', on=['Frame_ID'])
Evyatar2 = pd.merge(Evyatar2[Evyatar2['Hand_Type'] == 'left'], Evyatar2[Evyatar2['Hand_Type'] == 'right'], how='inner', on=['Frame_ID'])

newEvyatar1 = newEvyatar1.drop(columns=[' Frame ID_y',' Frame ID_x'])
Evyatar0= Evyatar0.drop(columns=['Frame_ID'])
Evyatar2= Evyatar2.drop(columns=['Frame_ID'])

Evyatar0['Category']='0'
Evyatar2['Category']='2'
newEvyatar1['Category']='1'

# %% [markdown]
# Now we can connect them:

# %%
DF2train.columns = newDF1train.columns = DF0train.columns
DF2ft.columns = newDF1ft.columns = DF0ft.columns
Evyatar2.columns =newEvyatar1.columns= Evyatar0.columns

# %%
Train = newDF1train.append(DF2train)
Train.append(DF0train)
Train
# Out:
#          Time_x Hand_Type_x  Number_of_hands_x  Position_X_x  Position_Y_x  \
# 0      128.2883       right                  1      15.67167      226.2064
# 1      128.3048       right                  1      16.24119      222.9389
# 2      128.3218       right                  1      16.72461      220.9709
# 3      128.3384       right                  1      17.09016      219.7124
# 4      128.3551       right                  1      17.46017      219.3652
# ...         ...         ...                ...           ...           ...
# 47688  856.1965        left                  2     -77.62601      173.7391
# 47689  856.2291        left                  2     -78.43058      176.0170
# 47690  856.2631        left                  2     -79.84506      180.2403
# 47691  856.2958        left                  2     -81.57359      183.5054
# 47692  856.3295        left                  2     -84.05124      187.8450
#
#        Position_Z_x  Velocity_X_x  Velocity_Y_x  Velocity_Z_x   Pitch_x  ...  \
# 0         20.264700      34.26665   -195.214700    -35.043020  0.270987  ...
# 1         20.117810      36.16443   -180.093900     -4.052799  0.245085  ...
# 2         19.949720      26.35298    -95.088190    -11.157620  0.230796  ...
# 3         19.676790      19.46804    -61.755180    -21.303780  0.217681  ...
# 4         19.131280      21.94964     -8.355943    -35.081790  0.220696  ...
# ...             ...           ...           ...           ...       ...  ...
# 47688    -14.213500     -46.75000     99.509110     71.012070  0.629213  ...
# 47689    -12.152660     -33.69026     98.243610     59.770540  0.667618  ...
# 47690     -9.015577     -68.45120    136.375800     87.632770  0.725945  ...
# 47691     -7.185198     -63.24731    121.752700     62.959700  0.762549  ...
# 47692     -5.172269     -57.17249    109.203600     58.481460  0.824793  ...
#
#        Wrist_Pos_X_y  Wrist_Pos_Y_y  Wrist_Pos_Z_y  Elbow_Pos_X_y  \
# 0          -114.6894       167.1053       2.444844      -339.3897
# 1          -114.4097       167.8733       1.127433      -336.8071
# 2          -114.2073       168.9353       0.130770      -333.6935
# 3          -114.4628       170.7293      -0.806436      -329.6519
# 4          -115.1224       172.6726      -1.665721      -326.1113
# ...              ...            ...            ...            ...
# 47688       129.1261       148.7041      62.824040       300.6781
# 47689       129.2868       148.1146      63.112180       285.6505
# 47690       131.8590       149.6264      66.098530       283.6185
# 47691       134.0416       151.5924      68.176930       288.9688
# 47692       137.0708       154.2158      71.469250       289.6567
#
#        Elbow_Pos_Y_y  Elbow_Pos_Z_y  Grab_Strenth_y  Grab_Angle_y  \
# 0           53.82746      -59.05448             0.0      0.505916
# 1           52.07711      -63.94888             0.0      0.753651
# 2           49.07627      -67.42601             0.0      1.100223
# 3           44.20391      -70.01109             0.0      1.515047
# 4           39.14006      -70.63696             0.0      1.474850
# ...              ...            ...             ...           ...
# 47688      -33.58672      128.75430             0.0      0.000000
# 47689      -53.66640      106.02620             0.0      0.000000
# 47690      -58.03491       95.29868             0.0      0.000000
# 47691      -54.13820       94.23959             0.0      0.000000
# 47692      -53.67185       93.98731             0.0      0.000000
#
#        Pinch_Strength_y  Category
# 0              0.025057         1
# 1              0.000000         1
# 2              0.000000         1
# 3              0.000000         1
# 4              0.000000         1
# ...                 ...       ...
# 47688          0.000000         2
# 47689          0.000000         2
# 47690          0.000000         2
# 47691          0.000000         2
# 47692          0.000000         2
#
# [81317 rows x 43 columns]

# %%
valid = newEvyatar1.append(Evyatar2)
valid.append(Evyatar0)
valid
# Out:
#         Time_x Hand_Type_x  Number_of_hands_x  Position_X_x  Position_Y_x  \
# 0     128.2883       right                  1      15.67167      226.2064
# 1     128.3048       right                  1      16.24119      222.9389
# 2     128.3218       right                  1      16.72461      220.9709
# 3     128.3384       right                  1      17.09016      219.7124
# 4     128.3551       right                  1      17.46017      219.3652
# ...        ...         ...                ...           ...           ...
# 4479  502.1338        left                  2     -94.49778      257.4222
# 4480  502.1499        left                  2     -94.05425      255.8155
# 4481  502.1665        left                  2     -93.68062      253.3679
# 4482  502.1830        left                  2     -93.12487      250.4072
# 4483  502.1996        left                  2     -92.35281      246.6158
#
#       Position_Z_x  Velocity_X_x  Velocity_Y_x  Velocity_Z_x   Pitch_x  ...  \
# 0         20.26470      34.26665   -195.214700    -35.043020  0.270987  ...
# 1         20.11781      36.16443   -180.093900     -4.052799  0.245085  ...
# 2         19.94972      26.35298    -95.088190    -11.157620  0.230796  ...
# 3         19.67679      19.46804    -61.755180    -21.303780  0.217681  ...
# 4         19.13128      21.94964     -8.355943    -35.081790  0.220696  ...
# ...            ...           ...           ...           ...       ...  ...
# 4479      55.64758      36.68623    -78.047370   -178.262600  1.323389  ...
# 4480      52.81230      30.15327   -144.977200   -155.627000  1.285448  ...
# 4481      50.37835      32.26988   -161.195300   -137.366600  1.246310  ...
# 4482      48.05837      32.14147   -157.050300   -124.679500  1.208146  ...
# 4483      45.84472      56.62387   -228.451000   -134.961700  1.180058  ...
#
#       Wrist_Pos_X_y  Wrist_Pos_Y_y  Wrist_Pos_Z_y  Elbow_Pos_X_y  \
# 0         -111.3281       216.7988       36.46680      -296.3193
# 1         -110.8031       213.5892       35.50308      -292.6761
# 2         -110.3644       209.8743       34.56297      -291.9227
# 3         -109.9222       204.8223       33.18878      -290.8479
# 4         -110.3149       201.4805       31.87729      -292.2361
# ...             ...            ...            ...            ...
# 4479       154.4715       151.6662       81.14725       367.3650
# 4480       154.3424       151.2262       79.87653       364.2306
# 4481       153.8897       150.4046       78.82951       362.5193
# 4482       153.5864       150.0203       78.10875       363.4342
# 4483       153.5919       150.3768       77.51683       364.0365
#
#       Elbow_Pos_Y_y  Elbow_Pos_Z_y  Grab_Strenth_y  Grab_Angle_y  \
# 0          55.25349      -24.22422             0.0      0.163973
# 1          49.54741      -27.85743             0.0      0.198828
# 2          46.27161      -30.80347             0.0      0.206514
# 3          40.44775      -31.99532             0.0      0.190320
# 4          38.33100      -33.61299             0.0      0.199012
# ...             ...            ...             ...           ...
# 4479       47.17764      167.21540             0.0      0.176508
# 4480       45.54407      171.67780             0.0      0.147999
# 4481       46.76253      175.68630             0.0      0.137555
# 4482       50.55334      176.69620             0.0      0.144381
# 4483       52.97089      176.88680             0.0      0.148039
#
#       Pinch_Strength_y  Category
# 0                  0.0         1
# 1                  0.0         1
# 2                  0.0         1
# 3                  0.0         1
# 4                  0.0         1
# ...                ...       ...
# 4479               0.0         2
# 4480               0.0         2
# 4481               0.0         2
# 4482               0.0         2
# 4483               0.0         2
#
# [8926 rows x 43 columns]

# %%
test = newDF1ft.append(DF2ft)
test.append(DF0ft)
test
# Out:
#          Time_x Hand_Type_x  Number_of_hands_x  Position_X_x  Position_Y_x  \
# 0      128.2883       right                  1      15.67167      226.2064
# 1      128.3048       right                  1      16.24119      222.9389
# 2      128.3218       right                  1      16.72461      220.9709
# 3      128.3384       right                  1      17.09016      219.7124
# 4      128.3551       right                  1      17.46017      219.3652
# ...         ...         ...                ...           ...           ...
# 10889  998.7513        left                  2     -98.32814      314.4973
# 10890  998.7836        left                  2     -97.31071      319.5955
# 10891  998.8158        left                  2     -96.74767      323.8981
# 10892  998.8495        left                  2     -95.67720      329.8123
# 10893  998.8855        left                  2     -94.29232      334.7815
#
#        Position_Z_x  Velocity_X_x  Velocity_Y_x  Velocity_Z_x   Pitch_x  ...  \
# 0          20.26470      34.26665   -195.214700    -35.043020  0.270987  ...
# 1          20.11781      36.16443   -180.093900     -4.052799  0.245085  ...
# 2          19.94972      26.35298    -95.088190    -11.157620  0.230796  ...
# 3          19.67679      19.46804    -61.755180    -21.303780  0.217681  ...
# 4          19.13128      21.94964     -8.355943    -35.081790  0.220696  ...
# ...             ...           ...           ...           ...       ...  ...
# 10889      75.12682      41.16818    115.850700     27.614590  1.611798  ...
# 10890      76.22157      31.36302    143.961000     30.502050  1.616390  ...
# 10891      76.98316      27.14988    185.621800     33.741870  1.619489  ...
# 10892      78.13316      47.37696    118.316700     24.152470  1.618042  ...
# 10893      78.81863      31.57111    132.410000     13.034000  1.617843  ...
#
#        Wrist_Pos_X_y  Wrist_Pos_Y_y  Wrist_Pos_Z_y  Elbow_Pos_X_y  \
# 0         -20.493800       164.0630       139.4900      -234.3876
# 1         -17.425560       163.4472       140.9099      -234.8178
# 2         -14.425290       163.0746       140.9692      -234.2492
# 3         -11.543290       163.4527       140.7151      -231.9865
# 4          -8.294804       164.6821       139.9044      -228.2753
# ...              ...            ...            ...            ...
# 10889     156.733700       255.0919       101.9025       341.0338
# 10890     157.584700       259.1192       102.1150       336.8353
# 10891     159.193200       263.2726       102.5311       332.9102
# 10892     163.032900       269.7217       103.0749       340.7914
# 10893     165.061600       270.7919       101.2590       344.8011
#
#        Elbow_Pos_Y_y  Elbow_Pos_Z_y  Grab_Strenth_y  Grab_Angle_y  \
# 0           56.10495       146.3018             0.0      0.521574
# 1           64.87560       162.7309             0.0      0.629741
# 2           73.16632       173.3089             0.0      0.718942
# 3           78.16240       180.4926             0.0      0.799123
# 4           85.16937       192.2322             0.0      0.917112
# ...              ...            ...             ...           ...
# 10889       65.01146       125.5006             0.0      0.000000
# 10890       64.01215       123.4790             0.0      0.000000
# 10891       62.99343       121.6264             0.0      0.000000
# 10892       72.96347       121.5707             0.0      0.024162
# 10893       75.97822       121.1411             0.0      0.025365
#
#        Pinch_Strength_y  Category
# 0                   0.0         1
# 1                   0.0         1
# 2                   0.0         1
# 3                   0.0         1
# 4                   0.0         1
# ...                 ...       ...
# 10889               0.0         2
# 10890               0.0         2
# 10891               0.0         2
# 10892               0.0         2
# 10893               0.0         2
#
# [22206 rows x 43 columns]

# %%
def Unify_rows(df):

    df['key'] = np.arange(0,df.shape[0])

    df0 = df[df['key']%3 == 0]
    df0['key'] = np.arange(0,df0.shape[0])

    df1 = df[df['key']%3 == 1]
    df1['key'] = np.arange(0,df1.shape[0])

    df2 = df[df['key']%3 == 2]
    df2['key'] = np.arange(0,df2.shape[0])

    df = pd.merge(df0, df1, how='inner', on=['key'])
    df = pd.merge(df, df2, how='inner', on=['key'])
    df = df.drop(columns=['key'])
    return df

Train= Unify_rows(Train)
valid= Unify_rows(valid)
test= Unify_rows(test)
# Out:
# <ipython-input-1354-35593de454d1>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['key'] = np.arange(0,df0.shape[0])
# <ipython-input-1354-35593de454d1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['key'] = np.arange(0,df1.shape[0])
# <ipython-input-1354-35593de454d1>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['key'] = np.arange(0,df2.shape[0])
# <ipython-input-1354-35593de454d1>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['key'] = np.arange(0,df0.shape[0])
# <ipython-input-1354-35593de454d1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['key'] = np.arange(0,df1.shape[0])
# <ipython-input-1354-35593de454d1>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['key'] = np.arange(0,df2.shape[0])
# <ipython-input-1354-35593de454d1>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['key'] = np.arange(0,df0.shape[0])
# <ipython-input-1354-35593de454d1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['key'] = np.arange(0,df1.shape[0])
# <ipython-input-1354-35593de454d1>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['key'] = np.arange(0,df2.shape[0])

# %%
test.columns.array
# Out:
# <PandasArray>
# [           'Time_x_x',       'Hand_Type_x_x', 'Number_of_hands_x_x',
#       'Position_X_x_x',      'Position_Y_x_x',      'Position_Z_x_x',
#       'Velocity_X_x_x',      'Velocity_Y_x_x',      'Velocity_Z_x_x',
#            'Pitch_x_x',
#  ...
#        'Wrist_Pos_X_y',       'Wrist_Pos_Y_y',       'Wrist_Pos_Z_y',
#        'Elbow_Pos_X_y',       'Elbow_Pos_Y_y',       'Elbow_Pos_Z_y',
#       'Grab_Strenth_y',        'Grab_Angle_y',    'Pinch_Strength_y',
#             'Category']
# Length: 129, dtype: object

# %%
Train
# Out:
#        Time_x_x Hand_Type_x_x  Number_of_hands_x_x  Position_X_x_x  \
# 0      128.2883         right                    1        15.67167
# 1      128.3384         right                    1        17.09016
# 2      128.3880         right                    1        18.20539
# 3      128.4380         right                    1        18.29336
# 4      128.4880         right                    1        18.41093
# ...         ...           ...                  ...             ...
# 27100  855.7963          left                    2       -67.80653
# 27101  855.8955          left                    2       -70.24233
# 27102  855.9966          left                    2       -75.16435
# 27103  856.0964          left                    2       -76.48546
# 27104  856.1965          left                    2       -77.62601
#
#        Position_Y_x_x  Position_Z_x_x  Velocity_X_x_x  Velocity_Y_x_x  \
# 0            226.2064        20.26470       34.266650     -195.214700
# 1            219.7124        19.67679       19.468040      -61.755180
# 2            218.9510        18.31486       17.508610        2.117375
# 3            222.1953        17.22853      -10.397290       97.658560
# 4            225.3138        17.95707        3.805511       38.830080
# ...               ...             ...             ...             ...
# 27100        140.8804       -29.61303      -15.119600       31.189600
# 27101        145.3648       -30.69582      -52.514450       82.300920
# 27102        154.5737       -25.26851      -20.332640       71.081500
# 27103        165.9167       -19.66159        7.361662       78.548930
# 27104        173.7391       -14.21350      -46.750000       99.509110
#
#        Velocity_Z_x_x  Pitch_x_x  ...  Wrist_Pos_X_y  Wrist_Pos_Y_y  \
# 0          -35.043020   0.270987  ...      -114.2073       168.9353
# 1          -21.303780   0.217681  ...      -116.0350       174.6689
# 2          -17.358420   0.237854  ...      -116.5078       178.0014
# 3          -15.440830   0.287074  ...      -117.0542       180.7438
# 4            7.956595   0.325778  ...      -121.3100       185.7180
# ...               ...        ...  ...            ...            ...
# 27100      -13.895900   0.045157  ...       131.3788       151.3617
# 27101       14.280840   0.079989  ...       132.3895       152.5022
# 27102       89.767150   0.195989  ...       130.7932       152.3160
# 27103       36.709110   0.458642  ...       129.3955       150.2528
# 27104       71.012070   0.629213  ...       131.8590       149.6264
#
#        Wrist_Pos_Z_y  Elbow_Pos_X_y  Elbow_Pos_Y_y  Elbow_Pos_Z_y  \
# 0           0.130770      -333.6935      49.076270      -67.42601
# 1          -2.587829      -326.9655      39.736880      -68.96506
# 2          -4.604100      -334.4683      50.908390      -63.29737
# 3          -8.568234      -328.9628      40.280620      -58.25848
# 4          -7.252874      -323.8270      30.369160      -51.50120
# ...              ...            ...            ...            ...
# 27100      59.448060       344.7464      53.416260      168.47910
# 27101      60.446040       343.7888      41.397530      160.31040
# 27102      61.863240       330.2462      25.779060      167.75800
# 27103      63.326110       318.3403      -1.043847      155.06500
# 27104      66.098530       283.6185     -58.034910       95.29868
#
#        Grab_Strenth_y  Grab_Angle_y  Pinch_Strength_y  Category
# 0                 0.0      1.100223          0.000000         1
# 1                 0.0      1.335021          0.042426         1
# 2                 0.0      1.147751          0.000000         1
# 3                 0.0      0.816796          0.000000         1
# 4                 0.0      0.879045          0.000000         1
# ...               ...           ...               ...       ...
# 27100             0.0      0.000000          0.000000         2
# 27101             0.0      0.000000          0.000000         2
# 27102             0.0      0.000000          0.000000         2
# 27103             0.0      0.000000          0.000000         2
# 27104             0.0      0.000000          0.000000         2
#
# [27105 rows x 129 columns]

# %%
valid
# Out:
#       Time_x_x Hand_Type_x_x  Number_of_hands_x_x  Position_X_x_x  \
# 0     128.2883         right                    1        15.67167
# 1     128.3384         right                    1        17.09016
# 2     128.3880         right                    1        18.20539
# 3     128.4380         right                    1        18.29336
# 4     128.4880         right                    1        18.41093
# ...        ...           ...                  ...             ...
# 2970  501.9517          left                    2       -99.99000
# 2971  502.0010          left                    2       -98.43592
# 2972  502.0505          left                    2       -96.11365
# 2973  502.1003          left                    2       -95.57066
# 2974  502.1499          left                    2       -94.05425
#
#       Position_Y_x_x  Position_Z_x_x  Velocity_X_x_x  Velocity_Y_x_x  \
# 0           226.2064        20.26470       34.266650     -195.214700
# 1           219.7124        19.67679       19.468040      -61.755180
# 2           218.9510        18.31486       17.508610        2.117375
# 3           222.1953        17.22853      -10.397290       97.658560
# 4           225.3138        17.95707        3.805511       38.830080
# ...              ...             ...             ...             ...
# 2970        234.0299        82.35533       80.826060      120.814300
# 2971        247.6726        75.92411       42.396310      221.301600
# 2972        252.7185        68.93648       49.596610       88.932530
# 2973        258.2673        61.63332       17.865480       81.657530
# 2974        255.8155        52.81230       30.153270     -144.977200
#
#       Velocity_Z_x_x  Pitch_x_x  ...  Wrist_Pos_X_y  Wrist_Pos_Y_y  \
# 0         -35.043020   0.270987  ...      -110.3644       209.8743
# 1         -21.303780   0.217681  ...      -111.7647       198.0587
# 2         -17.358420   0.237854  ...      -112.0632       183.2384
# 3         -15.440830   0.287074  ...      -112.9486       175.4666
# 4           7.956595   0.325778  ...      -115.3675       166.6530
# ...              ...        ...  ...            ...            ...
# 2970     -176.446800   1.627302  ...       156.3433       158.0314
# 2971     -133.816700   1.568801  ...       156.0077       155.0056
# 2972     -177.421600   1.493439  ...       153.1805       152.3382
# 2973     -146.266500   1.394268  ...       154.4715       151.6662
# 2974     -155.627000   1.285448  ...       153.5864       150.0203
#
#       Wrist_Pos_Z_y  Elbow_Pos_X_y  Elbow_Pos_Y_y  Elbow_Pos_Z_y  \
# 0          34.56297      -291.9227       46.27161      -30.80347
# 1          30.72762      -295.0816       36.28683      -34.28644
# 2          26.08182      -296.2053       19.74940      -31.92744
# 3          23.34489      -306.0939       19.80660      -26.32318
# 4          20.02584      -315.9833       19.47971      -25.63988
# ...             ...            ...            ...            ...
# 2970       89.32694       373.6405       51.87626      161.17600
# 2971       88.35492       376.2842       57.67886      163.55480
# 2972       84.09438       371.5746       56.97126      166.91000
# 2973       81.14725       367.3650       47.17764      167.21540
# 2974       78.10875       363.4342       50.55334      176.69620
#
#       Grab_Strenth_y  Grab_Angle_y  Pinch_Strength_y  Category
# 0                0.0      0.206514               0.0         1
# 1                0.0      0.203909               0.0         1
# 2                0.0      0.086200               0.0         1
# 3                0.0      0.079961               0.0         1
# 4                0.0      0.046181               0.0         1
# ...              ...           ...               ...       ...
# 2970             0.0      0.021872               0.0         2
# 2971             0.0      0.155045               0.0         2
# 2972             0.0      0.205578               0.0         2
# 2973             0.0      0.176508               0.0         2
# 2974             0.0      0.144381               0.0         2
#
# [2975 rows x 129 columns]

# %%
test
# Out:
#       Time_x_x Hand_Type_x_x  Number_of_hands_x_x  Position_X_x_x  \
# 0     128.2883         right                    1        15.67167
# 1     128.3384         right                    1        17.09016
# 2     128.3880         right                    1        18.20539
# 3     128.4380         right                    1        18.29336
# 4     128.4880         right                    1        18.41093
# ...        ...           ...                  ...             ...
# 7397  998.4169          left                    2      -105.36620
# 7398  998.5167          left                    2      -102.64350
# 7399  998.6179          left                    2      -101.34610
# 7400  998.7173          left                    2       -99.35220
# 7401  998.8158          left                    2       -96.74767
#
#       Position_Y_x_x  Position_Z_x_x  Velocity_X_x_x  Velocity_Y_x_x  \
# 0           226.2064        20.26470       34.266650     -195.214700
# 1           219.7124        19.67679       19.468040      -61.755180
# 2           218.9510        18.31486       17.508610        2.117375
# 3           222.1953        17.22853      -10.397290       97.658560
# 4           225.3138        17.95707        3.805511       38.830080
# ...              ...             ...             ...             ...
# 7397        247.9379        60.07058       45.859430      188.480700
# 7398        267.5888        64.91779       37.085420      208.864300
# 7399        291.2242        69.84669        7.997606      220.721100
# 7400        309.5378        73.90202       -8.915785      217.776300
# 7401        323.8981        76.98316       27.149880      185.621800
#
#       Velocity_Z_x_x  Pitch_x_x  ...  Wrist_Pos_X_y  Wrist_Pos_Y_y  \
# 0         -35.043020   0.270987  ...     -14.425290       163.0746
# 1         -21.303780   0.217681  ...      -5.394364       166.6063
# 2         -17.358420   0.237854  ...       1.524698       172.9114
# 3         -15.440830   0.287074  ...       7.796794       181.4475
# 4           7.956595   0.325778  ...      14.510280       193.1130
# ...              ...        ...  ...            ...            ...
# 7397       45.658770   1.551641  ...     159.567200       211.3093
# 7398       46.925310   1.576779  ...     157.580000       230.6143
# 7399       49.281750   1.599565  ...     155.568100       244.8627
# 7400       49.386850   1.602988  ...     157.584700       259.1192
# 7401       33.741870   1.619489  ...     165.061600       270.7919
#
#       Wrist_Pos_Z_y  Elbow_Pos_X_y  Elbow_Pos_Y_y  Elbow_Pos_Z_y  \
# 0         140.96920      -234.2492       73.16632       173.3089
# 1         138.86890      -223.7186       87.72292       198.5670
# 2         132.88170      -210.0589       84.72131       202.9303
# 3         123.94560      -202.6813       87.39080       189.5519
# 4         110.84780      -195.0950       98.13709       177.9083
# ...             ...            ...            ...            ...
# 7397       99.47881       372.2519       54.21946       126.7178
# 7398      101.29960       359.8433       60.20702       127.8493
# 7399      101.59310       339.2981       54.04735       123.6561
# 7400      102.11500       336.8353       64.01215       123.4790
# 7401      101.25900       344.8011       75.97822       121.1411
#
#       Grab_Strenth_y  Grab_Angle_y  Pinch_Strength_y  Category
# 0                0.0      0.718942          0.000000         1
# 1                0.0      1.042066          0.000000         1
# 2                0.0      0.796070          0.000000         1
# 3                0.0      0.724645          0.000000         1
# 4                0.0      0.837836          0.093845         1
# ...              ...           ...               ...       ...
# 7397             0.0      0.000000          0.000000         2
# 7398             0.0      0.000000          0.000000         2
# 7399             0.0      0.000000          0.000000         2
# 7400             0.0      0.000000          0.000000         2
# 7401             0.0      0.025365          0.000000         2
#
# [7402 rows x 129 columns]

# %%
# Train = Train.drop(columns=[' Hand_Type_x_x',' Hand_Type_y'])
# valid = valid.drop(columns=[' Hand_Type_x_x',' Hand_Type_y'])
# test = test.drop(columns=[' Hand_Type_x_x',' Hand_Type_y'])

# %%
test.columns.array
# Out:
# <PandasArray>
# [           'Time_x_x',       'Hand_Type_x_x', 'Number_of_hands_x_x',
#       'Position_X_x_x',      'Position_Y_x_x',      'Position_Z_x_x',
#       'Velocity_X_x_x',      'Velocity_Y_x_x',      'Velocity_Z_x_x',
#            'Pitch_x_x',
#  ...
#        'Wrist_Pos_X_y',       'Wrist_Pos_Y_y',       'Wrist_Pos_Z_y',
#        'Elbow_Pos_X_y',       'Elbow_Pos_Y_y',       'Elbow_Pos_Z_y',
#       'Grab_Strenth_y',        'Grab_Angle_y',    'Pinch_Strength_y',
#             'Category']
# Length: 129, dtype: object

# %%
test
# Out:
#       Time_x_x Hand_Type_x_x  Number_of_hands_x_x  Position_X_x_x  \
# 0     128.2883         right                    1        15.67167
# 1     128.3384         right                    1        17.09016
# 2     128.3880         right                    1        18.20539
# 3     128.4380         right                    1        18.29336
# 4     128.4880         right                    1        18.41093
# ...        ...           ...                  ...             ...
# 7397  998.4169          left                    2      -105.36620
# 7398  998.5167          left                    2      -102.64350
# 7399  998.6179          left                    2      -101.34610
# 7400  998.7173          left                    2       -99.35220
# 7401  998.8158          left                    2       -96.74767
#
#       Position_Y_x_x  Position_Z_x_x  Velocity_X_x_x  Velocity_Y_x_x  \
# 0           226.2064        20.26470       34.266650     -195.214700
# 1           219.7124        19.67679       19.468040      -61.755180
# 2           218.9510        18.31486       17.508610        2.117375
# 3           222.1953        17.22853      -10.397290       97.658560
# 4           225.3138        17.95707        3.805511       38.830080
# ...              ...             ...             ...             ...
# 7397        247.9379        60.07058       45.859430      188.480700
# 7398        267.5888        64.91779       37.085420      208.864300
# 7399        291.2242        69.84669        7.997606      220.721100
# 7400        309.5378        73.90202       -8.915785      217.776300
# 7401        323.8981        76.98316       27.149880      185.621800
#
#       Velocity_Z_x_x  Pitch_x_x  ...  Wrist_Pos_X_y  Wrist_Pos_Y_y  \
# 0         -35.043020   0.270987  ...     -14.425290       163.0746
# 1         -21.303780   0.217681  ...      -5.394364       166.6063
# 2         -17.358420   0.237854  ...       1.524698       172.9114
# 3         -15.440830   0.287074  ...       7.796794       181.4475
# 4           7.956595   0.325778  ...      14.510280       193.1130
# ...              ...        ...  ...            ...            ...
# 7397       45.658770   1.551641  ...     159.567200       211.3093
# 7398       46.925310   1.576779  ...     157.580000       230.6143
# 7399       49.281750   1.599565  ...     155.568100       244.8627
# 7400       49.386850   1.602988  ...     157.584700       259.1192
# 7401       33.741870   1.619489  ...     165.061600       270.7919
#
#       Wrist_Pos_Z_y  Elbow_Pos_X_y  Elbow_Pos_Y_y  Elbow_Pos_Z_y  \
# 0         140.96920      -234.2492       73.16632       173.3089
# 1         138.86890      -223.7186       87.72292       198.5670
# 2         132.88170      -210.0589       84.72131       202.9303
# 3         123.94560      -202.6813       87.39080       189.5519
# 4         110.84780      -195.0950       98.13709       177.9083
# ...             ...            ...            ...            ...
# 7397       99.47881       372.2519       54.21946       126.7178
# 7398      101.29960       359.8433       60.20702       127.8493
# 7399      101.59310       339.2981       54.04735       123.6561
# 7400      102.11500       336.8353       64.01215       123.4790
# 7401      101.25900       344.8011       75.97822       121.1411
#
#       Grab_Strenth_y  Grab_Angle_y  Pinch_Strength_y  Category
# 0                0.0      0.718942          0.000000         1
# 1                0.0      1.042066          0.000000         1
# 2                0.0      0.796070          0.000000         1
# 3                0.0      0.724645          0.000000         1
# 4                0.0      0.837836          0.093845         1
# ...              ...           ...               ...       ...
# 7397             0.0      0.000000          0.000000         2
# 7398             0.0      0.000000          0.000000         2
# 7399             0.0      0.000000          0.000000         2
# 7400             0.0      0.000000          0.000000         2
# 7401             0.0      0.025365          0.000000         2
#
# [7402 rows x 129 columns]

# %% [markdown]
# We have 3 data frames ready: validation, train and test.

# %% [markdown]
# ## Splitting

# %%
x_train = Train.drop('Category', axis=1) # all columns whthout prediction column 
y_train = Train.Category                 # prediction column

# %%
x_test = valid.drop('Category', axis=1) # all columns whthout prediction column 
y_test = valid.Category                 # prediction column

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=50)
X_train = pca.fit_transform(x_train)
X_test = pca.transform(x_test)
